# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pathlib import Path
from warnings import simplefilter

df = pd.read_csv(
    "data/book_sales.csv",
    index_col='Date',
    parse_dates=['Date'],
).drop('Paperback', axis=1)

df.head()
# Out:
#             Hardcover
# Date
# 2000-04-01        139
# 2000-04-02        128
# 2000-04-03        172
# 2000-04-04        139
# 2000-04-05        191

# %%
df['Time'] = np.arange(len(df.index)) # We could use (len(df.Date) if nit index_col=Date

df.head()
# Out:
#             Hardcover  Time
# Date
# 2000-04-01        139     0
# 2000-04-02        128     1
# 2000-04-03        172     2
# 2000-04-04        139     3
# 2000-04-05        191     4

# %%
# Linear regression

#plt.style.use("seaborn-whitegrid")
plt.rc(
    "figure",
    autolayout=True,
    figsize=(11, 4),
    titlesize=18,
    titleweight='bold',
)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=16,
    titlepad=10,
)
# %config InlineBackend.figure_format = 'retina'

fig, ax = plt.subplots()
ax.plot('Time', 'Hardcover', data=df, color='0.75')
ax = sns.regplot(x='Time', y='Hardcover', data=df, ci=95, scatter_kws=dict(color='0.25')) # This is regression line
ax.set_title('Time Plot of Hardcover Sales');

# %%
# Lag features. We shift values by 1 observations. It means we get info about the sales only next day
df['Lag_1'] = df['Hardcover'].shift(1)
df = df.reindex(columns=['Hardcover', 'Lag_1'])

df.head()
# Out:
#             Hardcover  Lag_1
# Date
# 2000-04-01        139    NaN
# 2000-04-02        128  139.0
# 2000-04-03        172  128.0
# 2000-04-04        139  172.0
# 2000-04-05        191  139.0

# %%
# Lag plots where each observation in a series is plotted against the previous observation

fig, ax = plt.subplots()
ax = sns.regplot(x='Lag_1', y='Hardcover', data=df, ci=None, scatter_kws=dict(color='0.25'))
ax.set_aspect('equal')
ax.set_title('Lag Plot of Hardcover Sales');

# %%
### Tunnel Traffic
